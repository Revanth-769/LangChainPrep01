# %%
pip install langchain langchain-openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show langchain langchain-core langchain-openai langchain-community

# %%
pip uninstall -y langchain langchain-core langchain-openai langchain-community langgraph
# Out:
# Found existing installation: langchain 1.2.6
# Uninstalling langchain-1.2.6:
#   Successfully uninstalled langchain-1.2.6
# Found existing installation: langchain-core 1.2.7
# Uninstalling langchain-core-1.2.7:
#   Successfully uninstalled langchain-core-1.2.7
# Found existing installation: langchain-openai 1.1.7
# Uninstalling langchain-openai-1.1.7:
#   Successfully uninstalled langchain-openai-1.1.7
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langgraph 1.0.6
# Uninstalling langgraph-1.0.6:
#   Successfully uninstalled langgraph-1.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U "langchain==0.3.27" "langchain-core==0.3.79" "langchain-openai==0.3.35" "langchain-community==0.3.27"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 50.6 MB/s  0:00:00
# ...
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 1.1.0
#     Uninstalling langchain-text-splitters-1.1.0:
#       Successfully uninstalled langchain-text-splitters-1.1.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [langchain-community]ngchain-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.1 requires langchain-core<2.0.0,>=1.2.5, but you have langchain-core 0.3.79 which is incompatible.
# langchain-classic 1.0.1 requires langchain-text-splitters<2.0.0,>=1.1.0, but you have langchain-text-splitters 0.3.11 which is incompatible.
# ...

# %%
import os
from langchain.tools import tool
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.agents.tool_calling_agent.base import create_tool_calling_agent
from langchain.agents import AgentExecutor
