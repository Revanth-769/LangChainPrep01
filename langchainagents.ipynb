# %%
pip install langchain langchain-openai

# %%
import os
from langchain.tools import tool
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.agents.tool_calling_agent.base import create_tool_calling_agent
from langchain.agents import AgentExecutor

# %%
pip show langchain langchain-core langchain-openai langchain-community
# Out:
# Name: langchain
# Version: 0.3.27
# Summary: Building applications with LLMs through composability
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: c:\users\scl\anaconda3\envs\lang\lib\site-packages
# Requires: async-timeout, langchain-core, langchain-text-splitters, langsmith, pydantic, PyYAML, requests, SQLAlchemy
# Required-by: langchain-community
# ---
# Name: langchain-core
# Version: 1.2.4
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: c:\users\scl\anaconda3\envs\lang\lib\site-packages
# Requires: jsonpatch, langsmith, packaging, pydantic, pyyaml, tenacity, typing-extensions, uuid-utils
# Required-by: langchain, langchain-community, langchain-openai, langchain-text-splitters, langgraph, langgraph-checkpoint, langgraph-prebuilt, langserve
# ---
# Name: langchain-openai
# Version: 1.1.6
# Summary: An integration package connecting OpenAI and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/openai
# Author:
# Author-email:
# License: MIT
# Location: c:\users\scl\anaconda3\envs\lang\lib\site-packages
# Requires: langchain-core, openai, tiktoken
# Required-by:
# ---
# Name: langchain-community
# Version: 0.3.29
# Summary: Community contributed LangChain integrations.
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: c:\users\scl\anaconda3\envs\lang\lib\site-packages
# Requires: aiohttp, dataclasses-json, httpx-sse, langchain, langchain-core, langsmith, numpy, pydantic-settings, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall -y langchain langchain-core langchain-openai langchain-community langgraph
# Out:
# Found existing installation: langchain 0.3.27
# Uninstalling langchain-0.3.27:
#   Successfully uninstalled langchain-0.3.27
# Found existing installation: langchain-core 1.2.4
# Uninstalling langchain-core-1.2.4:
#   Successfully uninstalled langchain-core-1.2.4
# Found existing installation: langchain-openai 1.1.6
# Uninstalling langchain-openai-1.1.6:
#   Successfully uninstalled langchain-openai-1.1.6
# Found existing installation: langchain-community 0.3.29
# Uninstalling langchain-community-0.3.29:
#   Successfully uninstalled langchain-community-0.3.29
# Found existing installation: langgraph 0.5.4
# Uninstalling langgraph-0.5.4:
#   Successfully uninstalled langgraph-0.5.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U "langchain==0.3.27" "langchain-core==0.3.79" "langchain-openai==0.3.35" "langchain-community==0.3.27"
# Out:
# Collecting langchain==0.3.27
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core==0.3.79
#   Using cached langchain_core-0.3.79-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-openai==0.3.35
#   Using cached langchain_openai-0.3.35-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain-community==0.3.27
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain==0.3.27) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-core==0.3.79) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-core==0.3.79) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-core==0.3.79) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-core==0.3.79) (25.0)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-openai==0.3.35) (2.14.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-openai==0.3.35) (0.12.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-community==0.3.27) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-community==0.3.27) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-community==0.3.27) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-community==0.3.27) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langchain-community==0.3.27) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core==0.3.79) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langsmith>=0.1.17->langchain==0.3.27) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langsmith>=0.1.17->langchain==0.3.27) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.23.0)
# Requirement already satisfied: anyio in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (4.9.0)
# Requirement already satisfied: certifi in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (1.0.9)
# Requirement already satisfied: idna in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai==0.3.35) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai==0.3.35) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai==0.3.35) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai==0.3.35) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.27) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from requests<3,>=2->langchain==0.3.27) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from requests<3,>=2->langchain==0.3.27) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.27) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai==0.3.35) (2025.11.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (1.1.0)
# Requirement already satisfied: colorama in c:\users\scl\anaconda3\envs\lang\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.104.2->langchain-openai==0.3.35) (0.4.6)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.79-py3-none-any.whl (449 kB)
# Using cached langchain_openai-0.3.35-py3-none-any.whl (75 kB)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Installing collected packages: langchain-core, langchain-openai, langchain, langchain-community
#
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    -------------------- ------------------- 2/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ------------------------------ --------- 3/4 [langchain-community]
#    ---------------------------------------- 4/4 [langchain-community]
#
# Successfully installed langchain-0.3.27 langchain-community-0.3.27 langchain-core-0.3.79 langchain-openai-0.3.35
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ["OPENAI_API_KEY"] = ""

# %%
@tool
def get_course_schedule(course_name: str) -> str:
    """
    Get the schedule for a given course."""
    
    schedule = {
        "ai architect mastery": "Mondays and Wednesdays, 6 PM - 8 PM",
        "data science bootcamp": "Tuesdays and Thursdays, 7 PM - 9 PM",
        "full stack development": "Saturdays, 10 AM - 4 PM",
    }
    key  = course_name.lower()
    return schedule.get(key, "Course not found.")

# %%
@tool
def calculate_discounted_price(original_price: float, discount_percentage: float) -> float:
    """
    Calculate the discounted price given the original price and discount percentage.
    """
    discount_amount = (discount_percentage / 100) * original_price
    discounted_price = original_price - discount_amount
    return round(discounted_price, 2)

# %%
@tool
def recommend_next(topic: str) -> str:
    """
    its a real life tool :whihc will help me out for next step recommendation for my learning path

    """
    t = topic.lower()
    if "python" in t:
        return (
            "next step for python is to learn web development using Django or Flask."
        )
    elif "data science" in t:
        return "next step for data science is to learn machine learning algorithms and their applications."
    elif "machine learning" in t:
        return "next step for machine learning is to learn deep learning and neural networks."
    else:
        return "Sorry, I don't have a recommendation for that topic."

# %%
tools = [get_course_schedule, calculate_discounted_price, recommend_next]

# %%
llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a helpful teaching assistant that helps students with learning paths and course-related queries.\n"
     "Use the tools to answer questions.\n"
     "Rules:\n"
     "1) If the question is about schedules/batches/timings, use get_course_schedule.\n"
     "2) If the question is about price/discount/GST/splits, use calc.\n"
     "3) If the question is about what to learn next, use recommend_next.\n"
     "4) If the user asks something outside these, respond:\n"
     "   'Sorry, I can only help with course schedules, discounted prices, and learning path recommendations.'\n"
     "If you use a tool, summarize the tool result in a human-readable way."
    ),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}"),
])

# %%
agent = create_tool_calling_agent(llm=llm, tools=tools, prompt=prompt)

# %%
executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# %%
demo_query = "I am learning Python. What should I learn next?"
response = executor.invoke({"input": demo_query})
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `recommend_next` with `{'topic': 'Python'}`
#
#
# next step for python is to learn web development using Django or Flask.Next, you should consider learning web development using frameworks like Django or Flask.
#
# > Finished chain.

# %%
demo_query = "tell me the schedule for AI Architect Mastery course"
response = executor.invoke({"input": demo_query})
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `get_course_schedule` with `{'course_name': 'AI Architect Mastery'}`
#
#
# Mondays and Wednesdays, 6 PM - 8 PMThe AI Architect Mastery course is scheduled for Mondays and Wednesdays from 6 PM to 8 PM.
#
# > Finished chain.
